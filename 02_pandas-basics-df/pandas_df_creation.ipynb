# %% [markdown]
# ## Create DataFrame with MySQL Table Data

# %%
#import required libs
import pandas as pd
import pymysql

# %%
#mysql connection creation

connect=pymysql.connect(
    host="localhost",
    user="root",
    password="@XYZ123@",
    database="org"
)

query="select * from employees"

df1=pd.read_sql(query,connect)

connect.close()
# Out:
# /var/folders/tf/pzv76cs179s0wbpclsrznz7w0000gn/T/ipykernel_69400/412994681.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1=pd.read_sql(query,connect)

# %%
df1
# Out:
#    emp_id first_name last_name                      email  phone_number  \
# 0       1       John       Doe         john.doe@email.com  123-456-7890
# 1       2       Jane     Smith       jane.smith@email.com  234-567-8901
# 2       3    Michael     Brown    michael.brown@email.com  345-678-9012
# 3       4      Emily   Johnson    emily.johnson@email.com  456-789-0123
# 4       5      David    Wilson     david.wilson@email.com  567-890-1234
# 5       6      Sarah     Davis      sarah.davis@email.com  678-901-2345
# 6       7      Chris  Martinez   chris.martinez@email.com  789-012-3456
# 7       8     Olivia  Anderson  olivia.anderson@email.com  890-123-4567
# 8       9     Daniel    Thomas    daniel.thomas@email.com  901-234-5678
# 9      10     Sophia     White     sophia.white@email.com  012-345-6789
#
#          department   salary   hire_date          created_at
# 0       Engineering  75000.0  2022-05-10 2025-03-02 10:51:29
# ...

# %%
df1.shape
# Out:
# (10, 9)

# %% [markdown]
# ## Create DataFrame with Dictionary Data

# %%
students = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma", "Frank", "Grace", "Hannah", "Ian", "Jack"],
    "Class": ["Grade 10", "Grade 9", "Grade 11", "Grade 8", "Grade 12", "Grade 10", "Grade 9", "Grade 11", "Grade 8", "Grade 12"]
}


df2=pd.DataFrame(students)
df2
# Out:
#       Name     Class
# 0    Alice  Grade 10
# 1      Bob   Grade 9
# 2  Charlie  Grade 11
# 3    David   Grade 8
# 4     Emma  Grade 12
# 5    Frank  Grade 10
# 6    Grace   Grade 9
# 7   Hannah  Grade 11
# 8      Ian   Grade 8
# 9     Jack  Grade 12

# %% [markdown]
# ## Create DataFrame with JSON Data

# %%
df3=pd.read_json('house_data.json')
df3
# Out:
#         location  rooms    cost
# 0       New York      3  500000
# 1  San Francisco      4  800000
# 2    Los Angeles      2  400000
# 3        Chicago      5  350000
# 4         Austin      3  450000

# %% [markdown]
# ## Create DataFrame with Excel Data

# %%
df4=pd.read_excel('financial data.xlsx')
df4
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df4.isnull().sum()
# Out:
# Segment                 0
# Country                 0
# Product                 0
# Discount Band          53
# Units Sold              0
# Manufacturing Price     0
# Sale Price              0
# Gross Sales             0
# Discounts               0
#  Sales                  0
# COGS                    0
# Profit                  0
# Date                    0
# Month Number            0
# Month Name              0
# Year                    0
# dtype: int64
